# %%
#!/usr/bin/env python
# !pip install ioh>=0.3.6
# Out:
# WARNING: You are using pip version 21.3.1; however, version 23.0 is available.
# You should consider upgrading via the '/home/erfan/7.WORK/cmtum/methods/coco/coco-optimization/venv/bin/python -m pip install --upgrade pip' command.

# %%
from ioh import problem, get_problem, ProblemType

import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize, Bounds

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
help(problem)
# Out:
# Help on module ioh.iohcpp.problem in ioh.iohcpp:
#
# NAME
#     ioh.iohcpp.problem - Module that includes all IOHExperimenter problems
#
# CLASSES
#     ioh.iohcpp.AbstractIntegerConstraint(pybind11_builtins.pybind11_object)
#         GraphConstraint
#         PWTConstraint
#     pybind11_builtins.pybind11_object(builtins.object)
#         IntegerSingleObjective
#             AbstractWModel
#                 WModelLeadingOnes
#                 WModelOneMax
#             GraphProblem
#                 MaxCoverage
#                 MaxCut
#                 MaxInfluence
#                 PackWhileTravel
#             IntegerSingleObjectiveWrappedProblem
#             PBO
#                 ConcatenatedTrap
#                 IsingRing
#                 IsingTorus
#                 IsingTriangular
#                 LABS
#                 LeadingOnes
#                 LeadingOnesDummy1
#                 LeadingOnesDummy2
#                 LeadingOnesEpistasis
# ...

# %%
f = get_problem(1, 1, 2, ProblemType.BBOB)
print(f)
# Out:
# <RealSingleObjectiveProblem 1. Sphere (iid=1 dim=2)>

# %%
f.state
# Out:
# <State evaluations: 0 optimum_found: false current_best: <Solution x: [2.247116418577895e+308, 2.247116418577895e+308] y: inf>>

# %%
f.optimum
# Out:
# <Solution x: [0.2528000000000006, -1.1568] y: 79.48>

# %%
f.problems
# Out:
# {1: 'Sphere',
#  2: 'Ellipsoid',
#  3: 'Rastrigin',
#  4: 'BuecheRastrigin',
#  5: 'LinearSlope',
#  6: 'AttractiveSector',
#  7: 'StepEllipsoid',
#  8: 'Rosenbrock',
#  9: 'RosenbrockRotated',
#  10: 'EllipsoidRotated',
#  11: 'Discus',
#  12: 'BentCigar',
#  13: 'SharpRidge',
#  14: 'DifferentPowers',
#  15: 'RastriginRotated',
#  16: 'Weierstrass',
#  17: 'Schaffers10',
#  18: 'Schaffers1000',
#  19: 'GriewankRosenBrock',
#  20: 'Schwefel',
#  21: 'Gallagher101',
#  22: 'Gallagher21',
#  23: 'Katsuura',
#  24: 'LunacekBiRastrigin',
#  30: 'UniformStarDiscrepancy10',
#  31: 'UniformStarDiscrepancy25',
#  32: 'UniformStarDiscrepancy50',
#  33: 'UniformStarDiscrepancy100',
#  34: 'UniformStarDiscrepancy150',
#  35: 'UniformStarDiscrepancy200',
#  36: 'UniformStarDiscrepancy250',
#  37: 'UniformStarDiscrepancy500',
#  38: 'UniformStarDiscrepancy750',
#  39: 'UniformStarDiscrepancy1000',
#  40: 'SobolStarDiscrepancy10',
#  41: 'SobolStarDiscrepancy25',
#  42: 'SobolStarDiscrepancy50',
# ...
